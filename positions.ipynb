# %%
import yfinance as yf

# Define the stock list
positions = [("CGNX",70.23),("NVDA",220.99),("SPCX",160.94),("STK",50.97),("FUN",64.26),("RCL",80.63)]
for position,cost in positions:
    # Fetch the ticker data
    ticker = yf.Ticker(position)

    # Get the current price from the info dictionary
    current_price = ticker.info.get('currentPrice')

    print(f"The current price for {position} is: ${current_price}, the cost was ${cost}")
# Out:
# The current price for CGNX is: $63.525, the cost was $70.23
# The current price for NVDA is: $203.45, the cost was $220.99
# The current price for SPCX is: $121.85, the cost was $160.94
# The current price for STK is: $49.31, the cost was $50.97
# The current price for FUN is: $17.37, the cost was $64.26
# The current price for RCL is: $286.3102, the cost was $80.63
