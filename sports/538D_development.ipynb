# %% [markdown]
# # 538D — Alex-sequenced Tier 1 model + fit (development)
#
# **Purpose:** Walk `5-Manuscript/Alex_Tier1_Sequential_Model_Outline.md` in order. This notebook builds the **data map** (\(Y\), \(L\) proxies, \(A\), diagnostics) the same way as **`535`**, but drops heavy **CELL 4 EDA** charts — those stay in `535` to avoid duplicate figures.
#
# **Run order:** EDIT BLANK (log) → **CELL 0** → **CELL 1** → **CELL 2** → **CELL 3** → **CELL 4** (binned means) → **CELL 4B** (exploratory Q × peer SD hexbin) → **CELL 5** (LPM + \(L^*\)) → **CELL 6** (logit + \(L^*\) in index space). Each numbered CELL is a **markdown** header immediately followed by a **code** cell whose first line is `# CELL N — …`. **Headers** start with **Does:** (what the next code cell *runs* or *produces*), then details and prerequisites.
#
# - **Reference panel:** `datasets/mbb/player_season_panel_530.csv` via `sports_pipeline.paths.panel_530_csv()` (refresh with **`530_sports_pipeline.ipynb`** when you need a new export).
# - **Simulation / comparative statics:** `537_Sports_Simulation.ipynb` only.
# - **Frozen / HPC-aligned copy:** `sports/538_alex_tier1_model_and_fit.ipynb` (Rivanna `faithful_538_sweep` + `sim_job_538.slurm`). Edit here in **538D**; after the sweep lands, promote 538D → 538 and retire this filename.

# %%
# EDIT BLANK — session log
##### EDIT BLANK ###### DISCARD
# session: 2026-06-01 14:44 — CELL 0 print HETEROGENEITY_TOP_TAIL
# - Session marker: 2026-06-01 14:44 — CELL 0 print HETEROGENEITY_TOP_TAIL
# - Session marker: 2026-06-01 14:43 — CELL 4D reads HETEROGENEITY_TOP_TAIL + reload
# - Session marker: 2026-06-01 14:43 — CELL 4D reads HETEROGENEITY_TOP_TAIL + reload
# - Session marker: 2026-06-01 14:39 — wire HETEROGENEITY_TOP_TAIL in CELL 0 + 4D
# - Session marker: 2026-06-01 14:39 — wire HETEROGENEITY_TOP_TAIL in CELL 0 + 4D
# - Session marker: 2026-06-01 14:34 — CELL 0 HETEROGENEITY_TOP_TAIL + RUN_CELL4D
# - Session marker: 2026-06-01 14:34 — CELL 0 HETEROGENEITY_TOP_TAIL + RUN_CELL4D
# - Session marker: 2026-06-01 11:38 — CELL 4D code cell (heterogeneity ventiles)
# - Session marker: 2026-06-01 11:38 — CELL 4D code cell (heterogeneity ventiles)
# - Session marker: 2026-06-01 10:25 — CELL 4D heterogeneity ventiles (Track A-1 briefing)
# - Session marker: 2026-06-01 10:25 — CELL 4D heterogeneity ventiles (Track A-1 briefing)
# - Session marker: 2026-05-23 12:17 — 10b reads tier1_539_reference_settings.json for rho
# - Session marker: 2026-05-23 12:17 — 10b reads tier1_539_reference_settings.json for rho
# - Session marker: 2026-05-22 18:27 — CELL 10b tau mirror slider under calibration plot
# - Session marker: 2026-05-22 13:56 — CELL 10 sliders companion cell (Cursor render fix)
# - Session marker: 2026-05-22 13:37 — CELL 10 diagnostic cell (widget panel health check)
# - Session marker: 2026-05-22 13:37 — 538D: title, CELL 0 labels, plot titles (items 1–3)
# - Session marker: 2026-05-21 14:05 — CELL 3 median θ count-crowding (530-aligned)
# - Session marker: 2026-05-19 18:12 — CELL 10: importlib.reload tier1 playground deps before exec
# - Session marker: 2026-05-19 15:11 — CELL 11/12: exec with __name__≠__main__ (fix double plots).
# - Session marker: 2026-05-19 15:09 — CELL 10 markdown header split from CELL 7 parked block.
# - Session marker: 2026-05-19 15:10 — CELL 11/12 markdown headers; fix double plot + import reload.
# - Session marker: 2026-05-19 15:01 — CELL 12 generative inverted-U bins; RUN_CELL11/12 in CELL 0.
# - Session marker: 2026-05-19 14:57 — J slider max 2500; CELL 11 530 mean×SD replay.
# - Session marker: 2026-05-19 14:20 — CELL 0: RUN_CELL10 gate for generative playground.
# - Session marker: 2026-05-19 14:19 — CELL 10 code: exec tier1_cell10_playground_run.py.
# - Session marker: 2026-05-19 14:18 — CELL 10 generative playground (Thread A); CELL 7 empirical parked.
# - Session marker: 2026-05-18 14:48 — CELL 5 plot: x-limits zoom to binned L range (+ L*).
# - Session marker: 2026-05-18 14:40 — CELL 5: plot fitted quadratic LPM vs raw L (Az=0) + L* line.
# - Session marker: 2026-05-18 14:36 — CELL 5–6 markdown: use $…$ for MathJax (replace \( … \) for reliable render).
# - Session marker: 2026-05-18 14:24 — CELL 4C: 3D surface via SciPy binned_statistic_2d (after user SciPy install).
# - Session marker: 2026-05-18 10:28 — CELL 4C: 3D surface mean Y_draft vs LOO Q × peer SD (same sample as 4B).
# - Session marker: 2026-05-18 10:27 — CELL 4B: histogram LOO peer mean Q excluding exact zeros.
# - Session marker: 2026-05-18 10:14 — CELL 4A: line plot draft rate vs bin mean L (CELL 4 companion).
# - Session marker: 2026-05-16 21:06 — 538: CELL markdown headers add “Does” (what each cell does).
# - Session marker: 2026-05-15 14:45 — CELL 6 logit (same index as CELL 5) + L* in z-space.
# - Session marker: 2026-05-15 14:27 — CELL 4–5 binned table + z-scored LPM and L*.
# - Session marker: 2026-05-15 12:49 — CELL 0–3 Alex scaffold (no 535 CELL4 EDA).
# - Session marker: 2026-05-15 16:20 — CELL 0: add RUN_CELL6 switch + uncomment print.
# - Session marker: 2026-05-15 16:32 — CELL 6: fix Logit res.params indexing (ndarray / Series).
# - Session marker: 2026-05-16 20:49 — CELL 4B: hexbin mean Q × LOO peer perf SD vs draft rate.
# - Session marker: 2026-05-16 21:06 — CELL 4A: line plot draft rate vs bin mean L (CELL 4 companion).
# - Session marker: 2026-05-18 10:14 — CELL 4B: histogram LOO peer mean Q excluding exact zeros.
# - Session marker: 2026-05-18 10:27 — CELL 4C: 3D surface mean Y_draft vs LOO Q × peer SD.

# %% [markdown]
# ### CELL 0 — Config · `RUN_CELL*` · knobs for Alex pipeline
#
# **Does:** Sets **run gates** (`RUN_CELL1` … `RUN_CELL6`, `RUN_CELL4B`) and **Tier 1 knobs** (`PERF_METRIC`, `PRIMARY_POOL_MODE`, minutes filter, crowding); prints one line summarizing them. Does **not** load the panel.
#
# Switchboard for **538D** only. Gates **CELL 1–6** and **CELL 4B** (… → binned table → **Q×SD hexbin** → LPM → **logit**). **No** 535-style dual-panel figure switches — use **`535`** for heavy EDA plots.
#
# Re-run this code cell after changing any flag.

# %%
# CELL 0 — Config · RUN_CELL* · knobs for Alex pipeline

# --- Run gates (re-run CELL 0 after changes) ---
RUN_CELL1 = True  # Environment · imports · CFG · panel path
RUN_CELL2 = True  # Load panel · perf · legacy poolq_loo
RUN_CELL3 = True  # Tier 1 mechanism columns (congestion_*)
RUN_CELL4 = True  # Alex §6 step 1 — binned mean Y vs L (table only)
RUN_CELL4B = True  # Exploratory — hexbin: LOO peer mean Q × LOO peer perf SD vs draft rate
RUN_CELL4D = True  # Track A-1 — draft rate vs poolq_loo by own-ability slice
RUN_CELL5 = True  # Alex §6 step 2 — LPM Y ~ L + L² + A on z-scores; print L*
RUN_CELL6 = True  # Alex §6 step 3 — logit same index as CELL 5; L* in z / raw L
RUN_CELL10 = True  # Generative pool playground (Thread A) — soft assign widgets
RUN_CELL10c = True  # 538 vs 539 calibration - τ auto-calibration
RUN_CELL11 = True  # 530 CELL 6 analog — mean vs pool SD on simulated rosters
RUN_CELL12 = True  # Generative inverted-U — binned promotion vs LOO poolq_loo

# --- Panel / Tier 1 (consumed by CELL 2–3 and later fit cells) ---
PERF_METRIC = "ppm"
# PERF_METRIC = "minutes"

# Rows below this minutes threshold dropped before Tier 1 group stats; None = keep all.
MIN_MINUTES_TIER1 = None

# "quality" → L proxy path favors congestion_quality (Tier 1 Q); "crowding" → crowding cols.
PRIMARY_POOL_MODE = "quality"
COMPUTE_WEIGHTED_CROWDING = False

# True → nested top 1/2.5/5/10% own perf (draft-scale); False → three-way 50% / p50–p90 / top 10%
HETEROGENEITY_TOP_TAIL = True

print(
    "538D CELL 0:",
    f"RUN_CELL1={RUN_CELL1}",
    f"RUN_CELL2={RUN_CELL2}",
    f"RUN_CELL3={RUN_CELL3}",
    f"RUN_CELL4={RUN_CELL4}",
    f"RUN_CELL4B={RUN_CELL4B}",
    f"RUN_CELL4D={RUN_CELL4D}",
    f"HETEROGENEITY_TOP_TAIL={HETEROGENEITY_TOP_TAIL}",
    f"RUN_CELL5={RUN_CELL5}",
    f"RUN_CELL6={RUN_CELL6}",
    f"RUN_CELL10={RUN_CELL10}",
    f"RUN_CELL10c={RUN_CELL10c}",
    f"RUN_CELL11={RUN_CELL11}",
    f"RUN_CELL12={RUN_CELL12}",
    f"PERF_METRIC={PERF_METRIC!r}",
    f"PRIMARY_POOL_MODE={PRIMARY_POOL_MODE!r}",
    f"COMPUTE_WEIGHTED_CROWDING={COMPUTE_WEIGHTED_CROWDING}",
)
# Out:
# 538D CELL 0: RUN_CELL1=True RUN_CELL2=True RUN_CELL3=True RUN_CELL4=True RUN_CELL4B=True RUN_CELL5=True RUN_CELL6=True RUN_CELL10=True RUN_CELL10c=True RUN_CELL11=True RUN_CELL12=True PERF_METRIC='ppm' PRIMARY_POOL_MODE='quality' COMPUTE_WEIGHTED_CROWDING=False

# %% [markdown]
# ## CELL 1 — Environment · imports · panel path
#
# **Does:** Imports pipeline modules, builds **`CFG`** (`PipelineConfig`: seasons, ventiles, winsor, z-score flags, …), and prints the **panel CSV path** / whether the file exists. Prepares globals for **`load_panel`** in CELL 2.
#
# **Alex outline:** sets up **§4 Map model to data** — same `PipelineConfig` + `panel_530_csv()` contract as **`535`**, without pulling in CELL 4 plotting helpers.
#
# - Run **CELL 0** first.
# - For an exact fresh panel, export from **`530_sports_pipeline.ipynb`** before loading here.

# %%
# CELL 1 — Environment · imports · panel path
from __future__ import annotations

if RUN_CELL1:
    from sports_pipeline import paths
    from sports_pipeline.panel_build import load_panel
    from sports_pipeline.config import PipelineConfig

    # Match 530 / 535 defaults; tighten binning in later fit cells if needed (Alex ladder starts descriptive).
    CFG = PipelineConfig(
        panel_season_min=2011,
        panel_season_max=2021,
        ventiles=20,
        poolq_binning="quantile",
        poolq_winsor_quantiles=(0.05, 0.95),
        # poolq_winsor_quantiles=(0.0, 1.0),
        perf_zscore_within_season=True,
        restrict_teams_by_draftees=False,
        draftee_restriction="season",
        min_minutes=0.0,
    )
    PANEL_PATH = paths.panel_530_csv()
    print("Panel CSV:", PANEL_PATH)
    print("Exists:", PANEL_PATH.is_file())
else:
    print("  CELL 1 skipped  (RUN_CELL1 = False in CELL 0)")
# Out:
# Panel CSV: /Users/charleslevine/Library/CloudStorage/Dropbox/1-Documents/00- Dissertation/0-Next_Chapter/Code_and_Data/New SQL and PY Code/Cursor Workspace PDE/datasets/mbb/player_season_panel_530.csv
# Exists: True

# %% [markdown]
# ### CELL 2 — Load panel · `perf` · legacy `poolq_loo`
#
# **Does:** Calls **`load_panel` → `apply_perf_metric_for_analysis`**, building **`df`** with **`Y_draft`**, **`perf`** (from `PERF_METRIC`), and recomputed **legacy `poolq_loo`** aligned to that `perf`.
#
# **Data map (Tier1_Briefing_Outline §4):** outcome **`Y_draft`**, own performance **`perf`**, legacy leave-self-out pool quality **`poolq_loo`**. Same `load_panel` + `apply_perf_metric_for_analysis` as **`535` CELL 2** — no extra logic.

# %%
# CELL 2 — Load panel · perf · legacy poolq_loo

if RUN_CELL2:
    if "CFG" not in globals():
        print("  CELL 2 skipped — CFG undefined; run CELL 0 then CELL 1.")
    else:
        import pandas as pd

        from sports_pipeline.panel_build import apply_perf_metric_for_analysis

        df = load_panel(CFG)
        smin = getattr(CFG, "panel_season_min", None)
        smax = getattr(CFG, "panel_season_max", None)
        if smin is not None:
            df = df.loc[pd.to_numeric(df["season"], errors="coerce") >= smin]
        if smax is not None:
            df = df.loc[pd.to_numeric(df["season"], errors="coerce") <= smax]
        df = apply_perf_metric_for_analysis(
            df,
            PERF_METRIC,
            poolq_winsor_quantiles=CFG.poolq_winsor_quantiles,
            zscore_perf_within_season=CFG.perf_zscore_within_season,
        )

        assert "Y_draft" in df.columns, "Panel must include Y_draft"
        assert "poolq_loo" in df.columns
        assert "minutes" in df.columns
else:
    print("  CELL 2 skipped  (RUN_CELL2 = False in CELL 0)")

# %% [markdown]
# ### CELL 3 — Tier 1 mechanism variables (`congestion_quality` · `congestion_crowding`)
#
# **Does:** Runs **`add_tier1_mechanism_variables`** on **`df`**, adding **`congestion_quality`**, **`peer_perf_sd_loo`**, **`congestion_crowding`** (and optional weighted crowding); sets **`ALEX_L_COL`** from **`PRIMARY_POOL_MODE`**.
#
# **Data map:** adds Tier 1 **`congestion_quality`** (strict valid-`perf` LOO mean), **`peer_perf_sd_loo`** (LOO sample SD of teammate `perf` among valid teammates), and crowding columns — same `add_tier1_mechanism_variables` as **`535` CELL 3**.
#
# Sets **`primary_x`**: the default pool column for **\(L\)** in later fit cells, from `PRIMARY_POOL_MODE` / `COMPUTE_WEIGHTED_CROWDING` in CELL 0. (Legacy **`poolq_loo`** remains available for side-by-side specs.)

# %%
# CELL 3 — Tier 1 mechanism variables (congestion_quality · congestion_crowding)
# θ calibrated like 530 CELL 5d (median drafted perf on within-season z if CFG says so).

THETA_STAT = "median"  # "median" | "max" — match 530 CELL 5d
PRIOR_DRAFT_SEASON_ONLY_THETA = False  # align with 530 CELL 5c default

if RUN_CELL3:
    if "df" not in globals():
        print("  CELL 3 skipped — df not defined; run CELL 2 or set RUN_CELL2 = True.")
    else:
        from sports_pipeline import panel_build
        from sports_pipeline.tier1_mechanism_vars import (
            TIER1_CROWDING_SUM_COL,
            TIER1_QUALITY_COL,
            TIER1_CROWDING_COL,
            TIER1_CROWDING_WEIGHTED_COL,
            add_tier1_mechanism_variables,
            tier1_primary_pool_column,
        )

        theta_rows = panel_build.drafted_perf_rows_for_theta(
            df,
            prior_draft_season_only=PRIOR_DRAFT_SEASON_ONLY_THETA,
        )
        VIABILITY_THETA = panel_build.viability_theta_drafted_perf(
            theta_rows, stat=THETA_STAT
        )
        THETA_MAX_DRAFTED = float(theta_rows["perf"].astype(float).max())

        df = add_tier1_mechanism_variables(
            df,
            min_minutes=MIN_MINUTES_TIER1,
            minutes_col="minutes",
            perf_col="perf",
            viability_theta=VIABILITY_THETA,
            crowding_mode="share",
            compute_weighted_crowding=COMPUTE_WEIGHTED_CROWDING,
        )

        if PRIMARY_POOL_MODE == "crowding" and COMPUTE_WEIGHTED_CROWDING:
            primary_x = TIER1_CROWDING_WEIGHTED_COL
        else:
            primary_x = tier1_primary_pool_column(PRIMARY_POOL_MODE)

        # Default amalgamated-L proxy for Alex §6 ladder (override in a later cell if needed).
        ALEX_L_COL = primary_x

        z_on = bool(getattr(CFG, "perf_zscore_within_season", False))
        print(
            f"θ ({THETA_STAT} drafted perf) = {VIABILITY_THETA:.4f}  |  "
            f"max drafted = {THETA_MAX_DRAFTED:.4f}  |  "
            f"theta rows n={len(theta_rows):,}  |  "
            f"within_season_z={z_on}"
        )
        print(
            TIER1_QUALITY_COL,
            TIER1_CROWDING_COL,
            TIER1_CROWDING_SUM_COL,
            TIER1_CROWDING_WEIGHTED_COL,
            "primary_x=",
            primary_x,
            "ALEX_L_COL=",
            ALEX_L_COL,
        )
else:
    print("  CELL 3 skipped  (RUN_CELL3 = False in CELL 0)")
# Out:
# θ (median drafted perf) = 0.7546  |  max drafted = 3.6707  |  theta rows n=1,136  |  within_season_z=True
# congestion_quality congestion_crowding congestion_crowding_sum congestion_crowding_weighted primary_x= congestion_quality ALEX_L_COL= congestion_quality

# %% [markdown]
# ### CELL 4 — Descriptive bins (Alex §6 step 1)
#
# **Does:** **Bins** `ALEX_L_COL` with **`assign_poolq_bin_labels`**, aggregates **`Y_draft`** (count and mean = draft rate) per bin, **displays** the resulting table — no plot.
#
# **No figure** — only a **table** of mean `Y_draft` by bins of **`ALEX_L_COL`**, using the same **`CFG.ventiles`** and **`CFG.poolq_binning`** as 530/535 (`assign_poolq_bin_labels`).
#
# **Sample:** `filter_panel(df, CFG)` then drop rows missing **`ALEX_L_COL`**, **`perf`**, **`Y_draft`** (matches the spirit of the EDA+LPM sample; heavy plots stay in **`535`**).

# %%
# CELL 4 — Descriptive bins on ALEX_L_COL (table only)

if RUN_CELL4:
    if "df" not in globals() or "ALEX_L_COL" not in globals():
        print("  CELL 4 skipped — run CELL 3 first.")
    elif "CFG" not in globals():
        print("  CELL 4 skipped — CFG missing; run CELL 1.")
    else:
        import pandas as pd
        from IPython.display import display

        from sports_pipeline.panel_build import assign_poolq_bin_labels, filter_panel

        use_alex = filter_panel(df, CFG)
        use_alex = use_alex.dropna(subset=[ALEX_L_COL, "perf", "Y_draft"])
        n_bins = int(CFG.ventiles)
        mode = str(CFG.poolq_binning)

        work = use_alex.copy()
        work["alex_bin"] = assign_poolq_bin_labels(work[ALEX_L_COL], n_bins, mode)
        work = work.dropna(subset=["alex_bin"])

        alex_bin_tab = (
            work.groupby("alex_bin", observed=True)
            .agg(
                n=("Y_draft", "size"),
                draft_rate=("Y_draft", "mean"),
                L_mean=(ALEX_L_COL, "mean"),
            )
            .reset_index()
            .sort_values("alex_bin")
        )

        print(
            f"CELL 4: n={len(use_alex):,} | bins={n_bins} | poolq_binning={mode!r} | L={ALEX_L_COL!r}"
        )
        display(alex_bin_tab)
else:
    print("  CELL 4 skipped  (RUN_CELL4 = False in CELL 0)")
# Out:
# CELL 4: n=82,887 | bins=20 | poolq_binning='quantile' | L='congestion_quality'
#     alex_bin     n  draft_rate    L_mean
# 0          0  4145    0.003378 -0.635805
# 1          1  4144    0.006757 -0.424096
# 2          2  4145    0.009168 -0.325468
# 3          3  4144    0.011824 -0.255602
# 4          4  4144    0.010135 -0.200844
# 5          5  4145    0.011098 -0.156354
# 6          6  4144    0.013996 -0.117048
# 7          7  4144    0.016409 -0.080703
# 8          8  4145    0.012786 -0.045682
# 9          9  4144    0.011100 -0.011957
# 10        10  4144    0.017133  0.021592
# 11        11  4145    0.016647  0.054539
# 12        12  4144    0.018340  0.087196
# 13        13  4144    0.018822  0.120662
# 14        14  4145    0.017129  0.156253
# 15        15  4144    0.017133  0.195985
# 16        16  4144    0.016892  0.242362
# 17        17  4145    0.019300  0.300478
# 18        18  4144    0.015685  0.389703
# 19        19  4144    0.010376  0.683475

# %%
# CELL 4A — Figure paired with CELL 4 (draft rate vs pool-quality bin)

if RUN_CELL4:
    if "df" not in globals() or "ALEX_L_COL" not in globals():
        print("  CELL 4A skipped — run CELL 3 first.")
    elif "CFG" not in globals():
        print("  CELL 4A skipped — CFG missing; run CELL 1.")
    else:
        import matplotlib.pyplot as plt
        import pandas as pd

        from sports_pipeline.panel_build import assign_poolq_bin_labels, filter_panel

        use_alex = filter_panel(df, CFG)
        use_alex = use_alex.dropna(subset=[ALEX_L_COL, "perf", "Y_draft"])
        n_bins = int(CFG.ventiles)
        mode = str(CFG.poolq_binning)

        work = use_alex.copy()
        work["alex_bin"] = assign_poolq_bin_labels(work[ALEX_L_COL], n_bins, mode)
        work = work.dropna(subset=["alex_bin"])

        alex_bin_tab = (
            work.groupby("alex_bin", observed=True)
            .agg(
                n=("Y_draft", "size"),
                draft_rate=("Y_draft", "mean"),
                L_mean=(ALEX_L_COL, "mean"),
            )
            .reset_index()
            .sort_values("alex_bin")
        )

        fig, ax = plt.subplots(figsize=(7, 3.6))
        ax.plot(
            alex_bin_tab["L_mean"],
            alex_bin_tab["draft_rate"],
            marker="o",
            linestyle="-",
            color="C0",
        )
        ax.set_xlabel(f"Mean {ALEX_L_COL} within bin")
        ax.set_ylabel("Draft rate (mean Y_draft)")
        ax.set_title(
            f"CELL 4A: draft rate vs bin-mean L | n_bins={n_bins} | {mode!r} | L={ALEX_L_COL!r}"
        )
        ax.grid(True, alpha=0.3)
        fig.tight_layout()
        plt.show()
else:
    print("  CELL 4A skipped  (RUN_CELL4 = False in CELL 0)")

# %% [markdown]
# ### CELL 4B — Exploratory mean \(Q\) × peer SD vs draft (Paper Directions 11)
#
# **Does:** After `filter_panel` + `dropna` on Q, peer SD, `perf`, and `Y_draft`, draws a **hexbin** with **x** = `congestion_quality`, **y** = `peer_perf_sd_loo`, **color** = mean **`Y_draft`**, and prints sample size / hex settings.
#
# **Hexbin:** *x* = **LOO peer mean `perf`** (`congestion_quality`, \(Q\)); *y* = **LOO peer `perf` SD** (`peer_perf_sd_loo` from CELL 3); color = **mean `Y_draft`** in each hex. **Associational** diagnostic — hypothesis from meeting: tight peer spread (low SD) may relate to stronger nonlinearity / “crowding”; high SD may ease peer distinction.
#
# **Needs:** **CELL 0** `RUN_CELL4B=True`, **CELL 1–3** (so `peer_perf_sd_loo` exists). The plot **always** uses **`congestion_quality`** on the x-axis even when **`PRIMARY_POOL_MODE`** is `'crowding'` (mean pool ability / Paper Directions 11).

# %%
# CELL 4B — Hexbin: LOO peer mean Q × LOO peer perf SD vs draft rate

if RUN_CELL4B:
    if "df" not in globals() or "ALEX_L_COL" not in globals():
        print("  CELL 4B skipped — run CELL 3 first.")
    elif "CFG" not in globals():
        print("  CELL 4B skipped — CFG missing; run CELL 1.")
    else:
        import matplotlib.pyplot as plt
        import numpy as np

        from sports_pipeline.panel_build import filter_panel
        from sports_pipeline.tier1_mechanism_vars import TIER1_PEER_PERF_SD_LOO_COL, TIER1_QUALITY_COL

        Q_COL = TIER1_QUALITY_COL
        SD_COL = TIER1_PEER_PERF_SD_LOO_COL

        use_h = filter_panel(df, CFG)
        need = [Q_COL, SD_COL, "perf", "Y_draft"]
        use_h = use_h.dropna(subset=need)
        n0 = len(use_h)

        HEX_GRID = 32
        HEX_MINCNT = 20

        fig, ax = plt.subplots(figsize=(8.2, 5.8))
        hb = ax.hexbin(
            use_h[Q_COL].to_numpy(dtype=float),
            use_h[SD_COL].to_numpy(dtype=float),
            C=use_h["Y_draft"].to_numpy(dtype=float),
            reduce_C_function=np.mean,
            gridsize=HEX_GRID,
            mincnt=HEX_MINCNT,
            cmap="viridis",
            edgecolors="none",
        )
        cb = fig.colorbar(hb, ax=ax)
        cb.set_label("Mean Y_draft in hex bin")
        ax.set_xlabel(r"LOO peer mean $perf$ (Tier 1 `congestion_quality`, $Q$)")
        ax.set_ylabel(r"LOO peer $perf$ SD (`peer_perf_sd_loo`, valid teammates, ddof=1)")
        ax.set_title(
            "538D · Exploratory draft rate vs pool mean × pool spread\n"
            "(20260515 Paper Directions 11; associational)"
        )
        fig.tight_layout()
        plt.show()

        q_all = use_h[Q_COL].to_numpy(dtype=float)
        mask_nz = q_all != 0
        q_nz = q_all[mask_nz]
        n_q_zero = int(np.sum(~mask_nz))
        fig2, ax2 = plt.subplots(figsize=(8.2, 4.2))
        ax2.hist(q_nz, bins=60, color="C0", edgecolor="white", linewidth=0.3)
        ax2.set_xlabel(
            r"LOO peer mean $perf$ (Tier 1 `congestion_quality`, $Q$) — exact 0 excluded"
        )
        ax2.set_ylabel("Count")
        ax2.set_title(
            f"CELL 4B · Histogram of LOO peer mean Q "
            f"(n={len(q_nz):,}; excluded Q=0: {n_q_zero:,})"
        )
        ax2.grid(True, alpha=0.3)
        fig2.tight_layout()
        plt.show()

        print(
            f"CELL 4B: n={n0:,} after dropna({need}) | hex gridsize={HEX_GRID} mincnt={HEX_MINCNT} | "
            f"PRIMARY_POOL_MODE={PRIMARY_POOL_MODE!r} (x-axis is always {Q_COL!r}) | "
            f"hist Q: n_nonzero={len(q_nz):,}, n_Q_eq_0={n_q_zero:,}"
        )
else:
    print("  CELL 4B skipped  (RUN_CELL4B = False in CELL 0)")
# Out:
# CELL 4B: n=82,871 after dropna(['congestion_quality', 'peer_perf_sd_loo', 'perf', 'Y_draft']) | hex gridsize=32 mincnt=20 | PRIMARY_POOL_MODE='quality' (x-axis is always 'congestion_quality') | hist Q: n_nonzero=82,871, n_Q_eq_0=0

# %%
# CELL 4C — 3D surface: mean Y_draft vs LOO Q × peer SD (SciPy `binned_statistic_2d`; same sample as 4B)

if RUN_CELL4B:
    if "df" not in globals() or "ALEX_L_COL" not in globals():
        print("  CELL 4C skipped — run CELL 3 first.")
    elif "CFG" not in globals():
        print("  CELL 4C skipped — CFG missing; run CELL 1.")
    else:
        import matplotlib.pyplot as plt
        import numpy as np
        from scipy.stats import binned_statistic_2d

        from sports_pipeline.panel_build import filter_panel
        from sports_pipeline.tier1_mechanism_vars import TIER1_PEER_PERF_SD_LOO_COL, TIER1_QUALITY_COL

        Q_COL = TIER1_QUALITY_COL
        SD_COL = TIER1_PEER_PERF_SD_LOO_COL

        use_h = filter_panel(df, CFG)
        need = [Q_COL, SD_COL, "perf", "Y_draft"]
        use_h = use_h.dropna(subset=need)

        x = use_h[Q_COL].to_numpy(dtype=float)
        y = use_h[SD_COL].to_numpy(dtype=float)
        c = use_h["Y_draft"].to_numpy(dtype=float)

        SURF_GRID = 40
        ret = binned_statistic_2d(x, y, c, statistic="mean", bins=SURF_GRID)
        Z = ret.statistic
        xe, ye = ret.x_edge, ret.y_edge
        xc = (xe[:-1] + xe[1:]) / 2
        yc = (ye[:-1] + ye[1:]) / 2
        X, Y = np.meshgrid(xc, yc, indexing="ij")

        fig = plt.figure(figsize=(9, 6.2))
        ax = fig.add_subplot(111, projection="3d")
        surf = ax.plot_surface(
            X,
            Y,
            Z,
            cmap="viridis",
            linewidth=0,
            antialiased=True,
            alpha=0.95,
        )
        ax.set_xlabel(r"LOO peer mean $Q$ (`congestion_quality`)")
        ax.set_ylabel(r"LOO peer $perf$ SD (`peer_perf_sd_loo`)")
        ax.set_zlabel("Mean Y_draft (bin)")
        ax.set_title(
            "538D · CELL 4C — mean draft rate vs (Q, peer SD)\n"
            f"(SciPy 2D mean bins={SURF_GRID}; associational; gated like CELL 4B)"
        )
        fig.colorbar(surf, ax=ax, shrink=0.55, pad=0.08, label="Mean Y_draft")
        fig.tight_layout()
        plt.show()

        n_finite = int(np.sum(np.isfinite(Z)))
        print(
            f"CELL 4C: n={len(use_h):,} | surface bins={SURF_GRID}×{SURF_GRID} | "
            f"cells_with_data={n_finite} | requires scipy.stats.binned_statistic_2d"
        )
else:
    print("  CELL 4C skipped  (RUN_CELL4B = False in CELL 0)")
# Out:
# CELL 4C: n=82,871 | surface bins=40×40 | cells_with_data=400 | requires scipy.stats.binned_statistic_2d

# %% [markdown]
# ### CELL 4D — Heterogeneity: draft rate vs pool quality by own-ability slice (Track A-1)
#
# **Does:** Plots **three** ventile curves on the **530 `poolq_loo` axis** — mean **`Y_draft`** vs binned LOO teammate quality — split by **own within-season `perf`** (bottom half / middle-high p50–p90 / top decile). Implementation: `sports/tier1_heterogeneity_ventiles.py` (called from the code cell below).
#
# **Prerequisites:** **CELL 0–2** (`df`, `CFG`, `PERF_METRIC`) **or** the script loads the panel directly if `df` is missing.
#
# ---
#
# #### Why this cell exists (motivation)
#
# The **pooled** inverted-U (530 ventiles, CELL 4/5) shows that advancement vs team quality **bends** on average. That is Layer 1 of the briefing: *we found a robust empirical regularity.*
#
# Alex / **constrained distinction** adds a sharper question (Layer 3 — the Wang move):
#
# > **Is everyone hurt equally by elite peer groups — or mainly the “maybe” players who are hard to distinguish from strong teammates?**
#
# **Track A-1** tests that prediction **without** waiting for the generative sim (CELL 10–12). If **curve shape** differs by slice — not just **height** — the downturn is plausibly about **substitutability / finite slots**, not merely “better players on better teams.”
#
# ---
#
# #### Where it fits in the overall message
#
# | Briefing section | This cell |
# |------------------|-----------|
# | **§1 Empirical discovery** | Uses the same **530 panel** and **`poolq_loo`** axis as the flagship ventile plot |
# | **§2 Mechanism (congestion)** | Tests **who** should bear congestion: marginals vs superstars vs non-prospects |
# | **§5 Minimal model** | Sets the **target** for Tier 1 sim: reproduce **heterogeneity**, not only one pooled hump |
#
# **Do not** present this figure as proof of congestion if the lines only differ in **level**. **Do** use it to show you are testing a **discriminating prediction** (VECTOR / Laszlo modeling section).
#
# ---
#
# #### How to read the figure
#
# | Slice | Mechanism prediction | If supported visually |
# |-------|----------------------|------------------------|
# | **Bottom 50%** own perf | Flat, low — never really in the draft pool | Line near zero across pool-quality bins |
# | **Middle-high (p50–p90)** | **Inverted-U or right-tail drop** — exposure helps until peers crowd | Rises then **falls** on the right |
# | **Top decile** | Stays high in elite pools — true standouts clear | High line; **no** large right-tail drop |
#
# **Honest first-pass result (June 2026):** on performance quantiles alone, the three lines often look **parallel** (different **levels**, similar **shapes**). That is a **null on this particular split** — not evidence against the pooled inverted-U. It means:
#
# 1. **Perf ventiles are too blunt** — “near-threshold” is not the same as p50–p90.
# 2. Next cuts: tighter band around draft viability θ, or **congestion** (`congestion_crowding`) splits after CELL 3.
# 3. **Tier 1 sim** should aim for **shape** separation by slice once congestion scale is fixed (CELL 10).
#
# The code cell prints slice **n** and overall draft rates; optional CSV under `datasets/mbb/exports_inverted_u_v0/`.
#
# ---
#
# #### Related files
#
# - `sports/tier1_heterogeneity_ventiles.py` — standalone script + `figure_heterogeneity_ventiles()`
# - `datasets/mbb/exports_inverted_u_v0/heterogeneity_ventiles_track_a1.png` — default export
# - Briefing outline: `1-Various_PDE_and_Chat_stuff/5-Manuscript/alex_gates_briefing_structure_outline_v4.md` (§5 modeling)

# %%
# CELL 4D — Heterogeneity ventiles (Track A-1; see markdown above)

_RUN_4D = globals().get("RUN_CELL4D", True)
if _RUN_4D:
    import importlib

    import matplotlib.pyplot as plt

    import tier1_heterogeneity_ventiles as het
    importlib.reload(het)

    from sports_pipeline import paths
    from sports_pipeline.panel_build import filter_panel

    _top_tail = bool(globals().get("HETEROGENEITY_TOP_TAIL", True))
    _mode = "top-tail" if _top_tail else "three-way"
    _slices = het.slice_set_for_mode(_mode)
    _slug = "top_tail" if _top_tail else "three_way"

    if "df" in globals() and "CFG" in globals():
        use = filter_panel(df, CFG).dropna(subset=["poolq_loo", "perf", "Y_draft"]).copy()
        n_bins = int(getattr(CFG, "ventiles", 20))
        bin_mode = str(getattr(CFG, "poolq_binning", "quantile"))
        print(f"CELL 4D: notebook sample n={len(use):,} (from CELL 2 df)")
    else:
        perf = globals().get("PERF_METRIC", "ppm")
        use = het.load_analysis_frame(perf_metric=perf)
        n_bins = 20
        bin_mode = "quantile"
        print(
            f"CELL 4D: standalone load n={len(use):,} "
            f"(run CELL 0–2 for same sample as rest of notebook)"
        )

    print(f"CELL 4D: HETEROGENEITY_TOP_TAIL={_top_tail}  mode={_mode!r}")

    fig, long = het.figure_heterogeneity_ventiles(
        use,
        slices=_slices,
        mode=_mode,
        n_bins=n_bins,
        bin_mode=bin_mode,
        title=f"538D · CELL 4D — draft rate vs poolq_loo ({_mode})",
    )

    for spec in _slices:
        m = spec.mask(use["perf"])
        rate = float(use.loc[m, "Y_draft"].mean()) if m.any() else float("nan")
        print(f"  {spec.name}: n={int(m.sum()):,}  overall draft rate={rate:.4f}")

    out_dir = paths.mbb_dir() / "exports_inverted_u_v0"
    out_dir.mkdir(parents=True, exist_ok=True)
    out_png = out_dir / f"heterogeneity_ventiles_{_slug}.png"
    out_csv = out_dir / f"heterogeneity_ventiles_{_slug}.csv"
    fig.savefig(out_png, dpi=150, bbox_inches="tight")
    long.to_csv(out_csv, index=False)
    plt.show()
    print(f"Wrote {out_png}")
    print(f"Wrote {out_csv}")
else:
    print("  CELL 4D skipped  (RUN_CELL4D = False in CELL 0)")
# Out:
# CELL 4D: notebook sample n=82,893 (from CELL 2 df)
#   bottom_half: n=41,446  overall draft rate=0.0021
#   middle_high: n=33,149  overall draft rate=0.0207
#   top_decile: n=8,298  overall draft rate=0.0439
# Wrote /Users/charleslevine/Library/CloudStorage/Dropbox/1-Documents/00- Dissertation/0-Next_Chapter/Code_and_Data/New SQL and PY Code/Cursor Workspace PDE/datasets/mbb/exports_inverted_u_v0/heterogeneity_ventiles_track_a1.png
# Wrote /Users/charleslevine/Library/CloudStorage/Dropbox/1-Documents/00- Dissertation/0-Next_Chapter/Code_and_Data/New SQL and PY Code/Cursor Workspace PDE/datasets/mbb/exports_inverted_u_v0/heterogeneity_ventiles_track_a1.csv

# %% [markdown]
# ### CELL 5 — Minimal quadratic LPM + $L^*$ (Alex §6 step 2)
#
# **Does:** Builds analysis sample (same filters as earlier cells), z-scores **`ALEX_L_COL`** and **`perf`**, fits **OLS** **`Y_draft ~ 1 + Lz + Lz² + Az`**, prints fitted coefficients and the **interior turning point** $L^*$ in z-units and mapped back to raw $L$.
#
# **Spec:** linear probability model $Y \sim 1 + \tilde L + \tilde L^2 + \tilde A$ where $\tilde L,\tilde A$ are **within-sample z-scores** of **`ALEX_L_COL`** and **`perf`**.
#
# **Interior turning point** (if $\hat\beta_2 \neq 0$): $\tilde L^* = -\hat\beta_1 / (2\hat\beta_2)$, mapped back to raw $L$ as $\bar L + s_L \tilde L^*$.
#
# **Next:** **CELL 6** fits the **same index** with **logit**; $\Pr(Y{=}1)=\Lambda(\beta_0+\beta_1\tilde L+\beta_2\tilde L^2+\beta_3\tilde A)$. With only $\tilde L$ and $\tilde L^2$ nonlinear, the **argmax of the linear index** (hence of fitted probability) is still $\tilde L^*=-\hat\beta_1/(2\hat\beta_2)$.

# %%
# CELL 5 — Quadratic LPM on z-scores; L* in z and raw L units

if RUN_CELL5:
    if "df" not in globals() or "ALEX_L_COL" not in globals():
        print("  CELL 5 skipped — run CELL 3 first.")
    elif "CFG" not in globals():
        print("  CELL 5 skipped — CFG missing; run CELL 1.")
    else:
        import numpy as np

        from sports_pipeline.panel_build import assign_poolq_bin_labels, filter_panel

        use_alex = filter_panel(df, CFG)
        use_alex = use_alex.dropna(subset=[ALEX_L_COL, "perf", "Y_draft"])

        L = use_alex[ALEX_L_COL].astype(float).to_numpy()
        A = use_alex["perf"].astype(float).to_numpy()
        y = use_alex["Y_draft"].astype(float).to_numpy()

        Lz = (L - L.mean()) / L.std(ddof=0)
        Az = (A - A.mean()) / A.std(ddof=0)
        X = np.column_stack([np.ones(len(y)), Lz, Lz * Lz, Az])
        mask = np.isfinite(X).all(axis=1) & np.isfinite(y)
        beta, *_ = np.linalg.lstsq(X[mask], y[mask], rcond=None)
        b0, b1, b2, b3 = beta
        L_mean = float(L.mean())
        L_std = float(L.std(ddof=0))

        print(
            f"CELL 5: OLS LPM  Y ~ 1 + Lz + Lz^2 + Az   (n={int(mask.sum()):,}, L={ALEX_L_COL!r})"
        )
        print(f"  beta_const={b0:.6f}  beta_Lz={b1:.6f}  beta_Lz2={b2:.6f}  beta_Az={b3:.6f}")

        if abs(b2) < 1e-12:
            print("  L* not defined (beta_Lz2 ~ 0).")
        else:
            Lstar_z = -b1 / (2 * b2)
            Lstar_raw = L_mean + L_std * Lstar_z
            print(f"  L* (z-score units) = {Lstar_z:.6f}")
            print(f"  L* (raw {ALEX_L_COL}) ≈ {Lstar_raw:.6f}")
            if b2 >= 0:
                print("  Note: beta_Lz2 >= 0 — no concave interior maximum; interpret shape cautiously.")

        import matplotlib.pyplot as plt

        n_bins = int(CFG.ventiles)
        mode = str(CFG.poolq_binning)
        work = use_alex.copy()
        work["alex_bin"] = assign_poolq_bin_labels(work[ALEX_L_COL], n_bins, mode)
        work = work.dropna(subset=["alex_bin"])
        alex_bin_tab = (
            work.groupby("alex_bin", observed=True)
            .agg(
                n=("Y_draft", "size"),
                draft_rate=("Y_draft", "mean"),
                L_mean=(ALEX_L_COL, "mean"),
            )
            .reset_index()
            .sort_values("alex_bin")
        )

        Lstar_raw_plot = None
        if abs(b2) >= 1e-12:
            Lstar_raw_plot = L_mean + L_std * (-b1 / (2 * b2))

        x_emp = alex_bin_tab["L_mean"].to_numpy(dtype=float)
        x_lo, x_hi = float(np.min(x_emp)), float(np.max(x_emp))
        if Lstar_raw_plot is not None:
            x_lo = min(x_lo, float(Lstar_raw_plot))
            x_hi = max(x_hi, float(Lstar_raw_plot))
        x_pad = max(0.05, 0.08 * (x_hi - x_lo))
        xlim_lo, xlim_hi = x_lo - x_pad, x_hi + x_pad

        L_grid = np.linspace(xlim_lo, xlim_hi, 200)
        Lz_grid = (L_grid - L_mean) / L_std
        y_hat = b0 + b1 * Lz_grid + b2 * Lz_grid**2 + b3 * 0.0

        y_emp = alex_bin_tab["draft_rate"].to_numpy(dtype=float)
        y_all = np.concatenate([y_emp, y_hat])
        y_lo, y_hi = float(np.min(y_all)), float(np.max(y_all))
        y_pad = max(0.001, 0.12 * (y_hi - y_lo))
        ylim_lo = max(0.0, y_lo - y_pad)
        ylim_hi = min(1.0, y_hi + y_pad)

        fig, ax = plt.subplots(figsize=(7, 4.2))
        ax.plot(
            alex_bin_tab["L_mean"],
            alex_bin_tab["draft_rate"],
            marker="o",
            linestyle="-",
            color="C0",
            lw=1.5,
            label=f"Binned mean Y_draft ({n_bins} bins, {mode!r})",
        )
        ax.plot(
            L_grid,
            y_hat,
            color="C1",
            lw=2,
            label="Fitted quadratic LPM (Az = 0)",
        )
        ax.set_xlabel(f"Mean {ALEX_L_COL} within bin / raw L")
        ax.set_ylabel("Draft rate (binned mean vs LPM fit)")
        ax.set_title(
            f"CELL 5 — binned draft rate (4A) + quadratic LPM | L={ALEX_L_COL!r}"
        )
        ax.set_xlim(xlim_lo, xlim_hi)
        ax.set_ylim(ylim_lo, ylim_hi)
        if Lstar_raw_plot is not None and xlim_lo <= Lstar_raw_plot <= xlim_hi:
            ax.axvline(
                Lstar_raw_plot,
                color="C3",
                ls="--",
                lw=1.2,
                label=f"L* ≈ {Lstar_raw_plot:.4g}",
            )
        ax.legend(loc="best", fontsize=9)
        ax.grid(True, alpha=0.3)
        fig.tight_layout()
        plt.show()
else:
    print("  CELL 5 skipped  (RUN_CELL5 = False in CELL 0)")
# Out:
# CELL 5: OLS LPM  Y ~ 1 + Lz + Lz^2 + Az   (n=82,887, L='congestion_quality')
#   beta_const=0.015010  beta_Lz=0.002851  beta_Lz2=-0.001305  beta_Az=0.010683
#   L* (z-score units) = 1.092590
#   L* (raw congestion_quality) ≈ 0.326679

# %% [markdown]
# ### CELL 6 — Logit (same $\tilde L,\tilde A$ index) + $L^*$
#
# **Does:** Reuses the **same rows and z-scores** as CELL 5, fits **MLE logit** `Y_draft ~ 1 + Lz + Lz² + Az`, prints the parameter vector and **$L^*$** from the linear index (same formula as CELL 5 when $\hat\beta_2<0$).
#
# **Needs:** `statsmodels` (`pip install statsmodels`).
#
# **$L^*$:** for coefficients $(\hat\beta_1,\hat\beta_2)$ on $(\tilde L,\tilde L^2)$, $\tilde L^* = -\hat\beta_1/(2\hat\beta_2)$; raw $L$ as in CELL 5. If **MLE** fails or $\hat\beta_2 \ge 0$, interpret cautiously.
#
# **Later:** SEs, season FE, clustering — new cells; keep this cell minimal.

# %%
# CELL 6 — Logit: Y ~ 1 + Lz + Lz^2 + Az (same z-scores as CELL 5); L* from index coeffs

if RUN_CELL6:
    if "df" not in globals() or "ALEX_L_COL" not in globals():
        print("  CELL 6 skipped — run CELL 3 first.")
    elif "CFG" not in globals():
        print("  CELL 6 skipped — CFG missing; run CELL 1.")
    else:
        try:
            import numpy as np
            import statsmodels.api as sm
        except ModuleNotFoundError:
            print("  CELL 6 skipped — install statsmodels: pip install statsmodels")
        else:
            from sports_pipeline.panel_build import filter_panel

            use_alex = filter_panel(df, CFG)
            use_alex = use_alex.dropna(subset=[ALEX_L_COL, "perf", "Y_draft"])

            L = use_alex[ALEX_L_COL].astype(float).to_numpy()
            A = use_alex["perf"].astype(float).to_numpy()
            y = use_alex["Y_draft"].astype(float).to_numpy()

            Lz = (L - L.mean()) / L.std(ddof=0)
            Az = (A - A.mean()) / A.std(ddof=0)
            X = np.column_stack([Lz, Lz * Lz, Az])
            X = sm.add_constant(X, has_constant="add")
            mask = np.isfinite(X).all(axis=1) & np.isfinite(y)
            y_i = y[mask].astype(int)
            if not np.all(np.isin(y_i, [0, 1])):
                print("  CELL 6 skipped — Y_draft must be 0/1 for logit.")
            else:
                try:
                    res = sm.Logit(y_i, X[mask]).fit(disp=False, maxiter=200)
                except Exception as exc:
                    print(f"  CELL 6: Logit failed ({exc!r}). Try simpler spec or check separation.")
                else:
                    b = res.params
                    # const, x1=Lz, x2=Lz^2, x3=Az (params may be Series or ndarray across statsmodels versions)
                    coef = np.asarray(b, dtype=float).ravel()
                    b0, b1, b2, b3 = float(coef[0]), float(coef[1]), float(coef[2]), float(coef[3])
                    print(
                        f"CELL 6: Logit  index = b0 + b1*Lz + b2*Lz^2 + b3*Az   (n={int(mask.sum()):,}, L={ALEX_L_COL!r})"
                    )
                    print(f"  b0={b0:.6f}  b1={b1:.6f}  b2={b2:.6f}  b3={b3:.6f}")
                    print(f"  log L = {res.llf:.4f}")

                    if abs(b2) < 1e-12:
                        print("  L* not defined (b2 ~ 0).")
                    else:
                        Lstar_z = -b1 / (2 * b2)
                        L_mean = float(L.mean())
                        L_std = float(L.std(ddof=0))
                        Lstar_raw = L_mean + L_std * Lstar_z
                        print(f"  L* (z-score units) = {Lstar_z:.6f}")
                        print(f"  L* (raw {ALEX_L_COL}) ≈ {Lstar_raw:.6f}")
                        if b2 >= 0:
                            print(
                                "  Note: b2 >= 0 — no concave maximum of the linear index; interpret cautiously."
                            )
else:
    print("  CELL 6 skipped  (RUN_CELL6 = False in CELL 0)")
# Out:
# CELL 6: Logit  index = b0 + b1*Lz + b2*Lz^2 + b3*Az   (n=82,887, L='congestion_quality')
#   b0=-4.210578  b1=0.358098  b2=-0.268392  b3=0.382489
#   log L = -5733.0263
#   L* (z-score units) = 0.667118
#   L* (raw congestion_quality) ≈ 0.199437

# %% [markdown]
# ### CELL 7 *(parked)* — Empirical inference & decomposition
#
# **Does:** **Not active** while we build **generative Thread A**. When resumed: cluster-robust SEs, season FE, alternative $L$ proxy — Alex §6 step 4 on **real** `(team_id, season)` pools (CELLs 0–6).

# %% [markdown]
# ## CELL 10 — Generative pool playground (Thread A)
#
# **Does:** **ipywidgets** panel (537 Cell 10 pattern) for **soft assignment** — draw $T_j$, draw $A_i$, assign rosters via `tier1_pool_assignment.py`. Plot **interval overlap** (530 CELL 8 analog): soft vs optional **sort-and-chop** benchmark.
#
# **Config:** Sliders are **authoritative**; **`tier1_sim_config.py`** = defaults only (“Load defaults from tier1_sim_config.py”). Engine: `sports/tier1_cell10_playground_run.py`.
#
# **Run order:**
# 1. **`# CELL 10 settings…`** — static plot/overlay booleans (edit rarely)
# 2. **`# CELL 10 — Generative pool playground…`** — once per kernel
#
# **Re-run playground** = refresh plots only. **Restart kernel** (or `del _CELL10_PLAYGROUND_LIVE`) to rebuild widgets.
#
# **Needs:** `ipywidgets`; **CELL 0** `RUN_CELL10=True`; does **not** require CELL 1–6. Glossary: `sports/documents/538_Cell10_Generative_Manual.md`. Calibrate $\tau$, $J$, roster size until coverage peak $\gg 1$ and median pool SD $\approx 0.8$ z.

# %% [markdown]
# ### CELL 10 settings — plot & overlay toggles (static)
#
# **Does:** Plain **boolean flags** (not live widgets). Edit the four variables, re-run this cell, then re-run **CELL 10 playground** (`del _CELL10_PLAYGROUND_LIVE` first if playground already ran this kernel). If unset, falls back to `tier1_sim_config.py` / `tier1_cell10_playground_state.json`.

# %%
# CELL 10 settings — static toggles (edit booleans; re-run before playground)
CELL10_SHOW_CHOP = False       # Plot A: overlay sort-and-chop (537 B)
CELL10_SHOW_PLOT_A = False     # interval overlap (530 CELL 8 analog)
CELL10_SHOW_PLOT_B = True      # inverted-U selection rate vs LOO L bins
CELL10_SHOW_PLOT_C = False     # synthetic A_i vs 530 perf histogram
CELL10_DEFER_PLOT_SECONDS = 0   # disable auto-plot; use Run button only

# %%
del _CELL10_PLAYGROUND_LIVE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 del _CELL10_PLAYGROUND_LIVE
#
# NameError: name '_CELL10_PLAYGROUND_LIVE' is not defined

# %%
# CELL 10 — Generative pool playground (ipywidgets · Thread A)

import importlib
import sys
from pathlib import Path


def reload_tier1_cell10_modules() -> None:
    """Reload Tier 1 playground deps so .py edits apply without kernel restart."""
    for mod_name in (
        "tier1_generative_eda",
        "tier1_pool_assignment",
        "tier1_sim_config",
        "sports_pipeline.empirical_perf_fit",
    ):
        mod = sys.modules.get(mod_name)
        if mod is not None:
            importlib.reload(mod)


# Gate: add RUN_CELL10 = True/False to CELL 0 when convenient; default run if unset.
if not globals().get("RUN_CELL10", True):
    print("  CELL 10 skipped  (RUN_CELL10 = False)")
else:
    _p = Path("sports/tier1_cell10_playground_run.py")
    if not _p.is_file():
        _p = Path("tier1_cell10_playground_run.py")
    if not _p.is_file() and Path.cwd().name == "sports":
        _p = Path("tier1_cell10_playground_run.py")
    if not _p.is_file():
        raise FileNotFoundError(
            "Missing tier1_cell10_playground_run.py — run from repo root "
            f"(cwd={Path.cwd().resolve()})"
        )
    reload_tier1_cell10_modules()
    exec(compile(_p.read_text(encoding="utf-8"), str(_p.resolve()), "exec"), globals())
# Out:
# VBox(children=(HTML(value='<b>538 CELL 10</b> — generative lab (pools + selection). Adjust sliders → plots ref…
# CELL 10: panel displayed — plots load shortly (or click Run / refresh plot)

# %%
# CELL 10b — 538 vs 539 calibration + τ mirror slider (under plot)
# Run after CELL 10 playground. Mirror links to globals()["w_tau"] when live.
# 539 ρ: tier1_539_reference_settings.json (run 539 plot cell first) unless you pass assortativity=...
from pathlib import Path
import importlib
import sys

_sports = Path("sports") if Path("sports/tier1_sim_config.py").is_file() else Path(".")
if str(_sports.resolve()) not in sys.path:
    sys.path.insert(0, str(_sports.resolve()))

import tier1_cell10_539_calibration_compare as cal

importlib.reload(cal)

_LINK_TAU = globals().get("w_tau")  # set by CELL 10 when playground is live
cal.display_calibration_panel(link_tau_widget=_LINK_TAU)

# One-shot: cal.compare_538_vs_539()
# Tau grid: cal.tau_sweep_hint(seed=1)
# Override ρ: cal.display_calibration_panel(assortativity=0.85, link_tau_widget=_LINK_TAU)
# Out:
# VBox(children=(HTML(value='<b>CELL 10b</b> — 538 vs 539 assignment calibration (same A_i draw; drag τ below pl…

# %%
# CELL 10c — 538 vs 539 calibration - τ auto-calibration
from pathlib import Path

if not globals().get("RUN_CELL10c", True):
    print("  CELL 10c skipped  (RUN_CELL10c = False in CELL 0)")
else:
    import importlib
    import tier1_cell10_539_calibration_compare as cal
    importlib.reload(cal)

    result = cal.auto_calibrate_tau(
        assortativity=0.88,
        apply_tau_widget=globals().get("w_tau"),  # push τ to CELL 10 slider
        persist_state=True,                       # write tier1_cell10_playground_state.json
    )
    result.tau          # best τ (3 dp)
    result.sweep        # full coarse + refine table
# Out:
# === auto_calibrate_tau (538 soft → 539 sort-chop) ===
# N=37,230  J=2482  roster=15  seed=0  rho=0.880
# 539 target: median_sd=0.1145  coverage_peak=1202.0
# Coarse grid: tau in [0.050, 0.450] step=0.010 (41 evals)…
# Refine: tau in [0.110, 0.150] step=0.001 (41 evals)…
# Wrote tau=0.128 → tier1_cell10_playground_state.json
#
# Best tau = 0.128  (loss=0.000033)
#   538: median_sd=0.1150  coverage_peak=1198.0
#   539: median_sd=0.1145  coverage_peak=1202.0
#   delta: median_sd=+0.0005  coverage_peak=-4.0
#   Applied to linked tau slider (run CELL 10 refresh if plots stale).

# %% [markdown]
# ### CELL 11 — Mean vs pool SD on simulated rosters (530 CELL 6 analog)
#
# **Does:** One soft-assignment draw using **CELL 10** knobs (`tier1_cell10_playground_state.json`); plots **pool mean vs pool SD** and **roster span** histogram. Calibrate toward median pool SD ~ 0.8.
#
# **Needs:** **CELL 0** `RUN_CELL11=True`; **CELL 10** run once first (state file). Manual: `sports/documents/538_Cell10_Generative_Manual.md`.

# %%
# CELL 11 — 530 CELL 6 analog on simulated rosters (mean vs pool SD · span)

from pathlib import Path

if not globals().get("RUN_CELL11", True):
    print("  CELL 11 skipped  (RUN_CELL11 = False in CELL 0)")
else:
    _p = Path("sports/tier1_cell11_replay_530.py")
    if not _p.is_file():
        _p = Path("tier1_cell11_replay_530.py")
    if not _p.is_file() and Path.cwd().name == "sports":
        _p = Path("tier1_cell11_replay_530.py")
    if not _p.is_file():
        raise FileNotFoundError(
            "Missing tier1_cell11_replay_530.py — run from repo root "
            f"(cwd={Path.cwd().resolve()})"
        )
    # exec into notebook globals() would set __name__=='__main__' and run if __name__ block twice
    _ns = {"__builtins__": __builtins__, "__name__": "tier1_cell11_replay_530"}
    exec(compile(_p.read_text(encoding="utf-8"), str(_p.resolve()), "exec"), _ns)
    _ns["run_cell11"]()
# Out:
# CELL 11: sim rosters J=2482 roster=15 N=37230 seed=91048
#   (large J — assignment may take a while)
#   median pool_sd=0.114  median span=0.391  r(mean,sd)=-0.025
#   530 targets: median roster SD ~ 0.8; weak positive mean–SD link OK

# %% [markdown]
# ### CELL 12 — Generative inverted-U (binned promotion vs LOO poolq_loo)
#
# **Does:** Alex §6 step 1 on **simulated** rosters: LOO `poolq_loo` → **~12 bins** → mean **`Y_promoted`** (bar/line). Uses CELL 10 assignment + promotion knobs in **`tier1_sim_config.py`** (`N_PROMOTED`, `PROMOTION_SCORE_MODE`, …).
#
# **Needs:** **CELL 0** `RUN_CELL12=True`; **CELL 10** state JSON. If `assign_promotion` import fails, **restart kernel** and re-run **CELL 0 → 10 → 12**.

# %%
# CELL 12 — Generative inverted-U (binned promotion vs LOO poolq_loo)

from pathlib import Path

if not globals().get("RUN_CELL12", True):
    print("  CELL 12 skipped  (RUN_CELL12 = False in CELL 0)")
else:
    _p = Path("sports/tier1_cell12_generative_eda.py")
    if not _p.is_file():
        _p = Path("tier1_cell12_generative_eda.py")
    if not _p.is_file() and Path.cwd().name == "sports":
        _p = Path("tier1_cell12_generative_eda.py")
    if not _p.is_file():
        raise FileNotFoundError(
            "Missing tier1_cell12_generative_eda.py — run from repo root "
            f"(cwd={Path.cwd().resolve()})"
        )
    _ns = {"__builtins__": __builtins__, "__name__": "tier1_cell12_generative_eda"}
    exec(compile(_p.read_text(encoding="utf-8"), str(_p.resolve()), "exec"), _ns)
    _ns["run_cell12"]()
# Out:
# CELL 12: soft assign J=2482 N=37230 L='crowding_smooth' bins=25 K=4040 score='loo_gap_plus_ability' winner='C' seed=91048
#   (pool + selection knobs from tier1_cell10_playground_state.json)
#  bin    n  selection_rate  mean_loo_q
#    0 1490        0.000671    0.092108
#    1 1489        0.000672    0.117225
#    2 1489        0.003358    0.138135
#    3 1489        0.002015    0.161600
#    4 1489        0.006044    0.189444
#    5 1490        0.008054    0.220317
#    6 1489        0.012089    0.256963
#    7 1489        0.020819    0.300782
#    8 1489        0.057085    0.342834
#    9 1489        0.069174    0.381626
#   10 1490        0.097987    0.422231
#   11 1489        0.145735    0.464248
#   12 1489        0.190732    0.508180
#   13 1489        0.213566    0.549927
#   14 1489        0.217596    0.588749
#   15 1490        0.218792    0.624226
#   16 1489        0.225655    0.660846
#   17 1489        0.220282    0.702334
#   18 1489        0.262592    0.745143
#   19 1489        0.205507    0.778014
#   20 1490        0.197987    0.810188
#   21 1489        0.161182    0.842038
#   22 1489        0.134318    0.865532
#   23 1489        0.040967    0.885140
#   24 1489        0.000000    0.908827
