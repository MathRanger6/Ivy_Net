# %% [markdown]
# # 540 — Three-step sim (re-entry)
#
# **For later Charles:** this notebook does **not** implement the DGP. It only (1) points at export folders, (2) optionally re-runs the Pass A / Pass B **scripts**, (3) displays the PNGs.
#
# | Pass | Question | Script | Export folder |
# |------|----------|--------|---------------|
# | **A** | Congestion in the **score**? (λ=0 vs λ>0) | `scripts/hero_model_reset_bundle.py` | `alex_side_by_side_v0/` |
# | **B** | Does **ρ** (assignment) move the curve? (score+K fixed) | `scripts/540_rho_ablation_bundle.py` | `alex_rho_ablation_v0/` |
#
# **Engines (shared libraries):** `tier1_pool_assignment.py`, `tier1_generative_eda.py`, `tier1_sim_config.py`
# **Not this path:** `tier1_cell10_playground_run.py` (LEGACY 538 widget UI)
#
# **Spec / checklist:** [`540_READ_ME_SIM.md`](540_READ_ME_SIM.md) · [`CHARLES_CHECKLIST.md`](../3-Master_Plan/re_entry/CHARLES_CHECKLIST.md) · [`model_OPORD.md`](../3-Master_Plan/re_entry/model_OPORD.md)
#
# **Pipeline reminder:** assign (`ρ`) → score (`S_i`, λ) → select (top K).

# %%
##### EDIT BLANK ###### DISCARD
# session: 2026-07-28 17:32 — commenting / file-map for later Charles
# - Session marker: 2026-07-27 17:41 — 540 three-step sim re-entry

# %%
from pathlib import Path
import subprocess
import sys

# Resolve repo root whether kernel cwd is repo/ or sports/
NB = Path.cwd()
REPO = NB if (NB / "sports" / "540_READ_ME_SIM.md").is_file() else NB.parent
SPORTS = REPO / "sports"
# Pass A = λ knockout (score); Pass B = ρ ablation (assignment)
EXPORT_A = SPORTS / "datasets/mbb/exports_inverted_u_v0/alex_side_by_side_v0"
EXPORT_B = SPORTS / "datasets/mbb/exports_inverted_u_v0/alex_rho_ablation_v0"

print("Repo:", REPO)
print("Pass A (λ knockout):", EXPORT_A)
print("Pass B (ρ ablation):", EXPORT_B)
print("Tip: prefer running scripts from a terminal so you see full logs:")
print("  python sports/scripts/hero_model_reset_bundle.py")
print("  python sports/scripts/540_rho_ablation_bundle.py")

# %%
# Optional re-run of Pass A then Pass B (same as terminal commands above).
# Checklist: you should run these yourself at least once and inspect exports.
RUN = False  # set True to regenerate both bundles from this cell

if RUN:
    print("Pass A — λ knockout …")
    subprocess.run(
        [sys.executable, str(SPORTS / "scripts/hero_model_reset_bundle.py")],
        cwd=REPO,
        check=True,
    )
    print("Pass B — ρ ablation …")
    subprocess.run(
        [sys.executable, str(SPORTS / "scripts/540_rho_ablation_bundle.py")],
        cwd=REPO,
        check=True,
    )
    print("Done. See EXPORT_A / EXPORT_B.")
else:
    print("Skipping re-run (RUN=False). Open export folders above, or set RUN=True.")

# %%
from IPython.display import Image, display

for label, folder, name in [
    ("Pass A — λ knockout", EXPORT_A, "inverted_u_side_by_side_empirical_vs_generative.png"),
    ("Pass B — ρ ablation", EXPORT_B, "rho_ablation_selection_by_poolq_loo.png"),
]:
    path = folder / name
    print(label, path)
    if path.is_file():
        display(Image(filename=str(path)))
    else:
        print("  (missing — set RUN=True in previous cell)")
